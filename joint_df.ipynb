# %%
import json
import pandas as pd

# %%
df_joint = pd.read_csv('joint_df_for_bounding_boxes.csv')
df_joint['Station Name'].unique()
# Out:
# array(['Embarcadero', 'Montgomery Street', 'Powell Street',
#        'Civic Center', '16th Street Mission', '24th Street Mission',
#        'Glen Park', 'Balboa Park'], dtype=object)

# %%
with open('bart_sf_few.json', 'r') as f:
    df_bart_json = json.load(f)
bart_list=[]
for item in df_bart_json['features']:
    bart_dict = dict()
    bart_dict['station_name'] = item['properties']['station']
    bart_dict['lon']=item['geometry']['coordinates'][0]
    bart_dict['lat']=item['geometry']['coordinates'][1]
    bart_list.append(bart_dict)
# df_bart_json['features']
df_bart = pd.DataFrame(bart_list)
# bart_final = ['16TH STREET & MISSION', '24TH STREET & MISSION', 'Balboa Park',
#       'Civic Center', 'Embarcadero', 'Glen Park', 'Montgomery Street',
#       'Powell Street','CIVIC CENTER/ UN PLAZA']
bart_final = ['Embarcadero', 'Montgomery Street', 'Powell Street',
       'CIVIC CENTER/ UN PLAZA', '16th Street & Mission', '24th Street & Mission', 'Glen Park', 'Balboa Park']
bart_final = [x.upper() for x in bart_final]
df_bart_final =df_bart.loc[df_bart['station_name'].isin(bart_final)]
bounding_limit = 0.0025
df_bart_final['x_min'] = df_bart_final['lat']-bounding_limit
df_bart_final['x_max'] = df_bart_final['lat']+bounding_limit
df_bart_final['y_min'] = df_bart_final['lon']-bounding_limit
df_bart_final['y_max'] = df_bart_final['lon']+bounding_limit

df_powell = df_bart_final.loc[(df_bart_final['station_name']=='POWELL STREET')]
df_montgomery = df_bart_final.loc[(df_bart_final['station_name']=='MONTGOMERY STREET')]
df_16 = df_bart_final.loc[(df_bart_final['station_name']=='16TH STREET & MISSION')]
df_24 = df_bart_final.loc[(df_bart_final['station_name']=='24TH STREET & MISSION')] 
df_embarcadero= df_bart_final.loc[(df_bart_final['station_name']=='EMBARCADERO')]
df_civic_center = df_bart_final.loc[(df_bart_final['station_name']=='CIVIC CENTER/ UN PLAZA')]
df_glen_park = df_bart_final.loc[(df_bart_final['station_name']=='GLEN PARK')] 
df_balboa_park = df_bart_final.loc[(df_bart_final['station_name']=='BALBOA PARK')]
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_joint.loc[(df_joint['Latitude'] >= float(df_embarcadero['x_min'])) 
           & (df_joint['Latitude'] <=float(df_embarcadero['x_max'])) 
           & (df_joint['Longitude'] >= float(df_embarcadero['y_min'])) 
           & (df_joint['Longitude'] <=float(df_embarcadero['y_max'])), 'station_flag'] = 'Embarcadero'

df_joint.loc[(df_joint['station_flag']=='Embarcadero')]
# Out:
#        Unnamed: 0  Exit Station         Exits         tabname   Station Name  \
# 10             10            25  47987.571429  Avg Weekday OD    Embarcadero
# 35             35            25  47987.571429  Avg Weekday OD    Embarcadero
# 36             36            25  47987.571429  Avg Weekday OD    Embarcadero
# 39             39            25  47987.571429  Avg Weekday OD    Embarcadero
# 67             67            25  47987.571429  Avg Weekday OD    Embarcadero
# ...           ...           ...           ...             ...            ...
# 24294       24294            27  25415.526316  Avg Weekday OD  Powell Street
# 24301       24301            27  25415.526316  Avg Weekday OD  Powell Street
# 24316       24316            27  25415.526316  Avg Weekday OD  Powell Street
# 24331       24331            27  25415.526316  Avg Weekday OD  Powell Street
# 24332       24332            27  25415.526316  Avg Weekday OD  Powell Street
#
# ...

# %%
df_joint.loc[(df_joint['Latitude'] >= float(df_16['x_min'])) 
           & (df_joint['Latitude'] <=float(df_16['x_max'])) 
           & (df_joint['Longitude'] >= float(df_16['y_min'])) 
           & (df_joint['Longitude'] <=float(df_16['y_max'])), 'station_flag'] = '16th Mission Street'

df_joint.loc[(df_joint['station_flag']=='16th Mission Street')]
# Out:
#        Unnamed: 0  Exit Station         Exits         tabname  \
# 1838         1838            29  12183.000000  Avg Weekday OD
# 1839         1839            29  12183.000000  Avg Weekday OD
# 1846         1846            29  12183.000000  Avg Weekday OD
# 1861         1861            29  12183.000000  Avg Weekday OD
# 1863         1863            29  12183.000000  Avg Weekday OD
# ...           ...           ...           ...             ...
# 26383       26383            30  12038.894737  Avg Weekday OD
# 26392       26392            30  12038.894737  Avg Weekday OD
# 26403       26403            30  12038.894737  Avg Weekday OD
# 26407       26407            30  12038.894737  Avg Weekday OD
# 26411       26411            30  12038.894737  Avg Weekday OD
#
#               Station Name Analysis Neighborhood               filename  \
# 1838   16th Street Mission               Mission  Ridership_201901.xlsx
# 1839   16th Street Mission               Mission  Ridership_201901.xlsx
# ...

# %%
df_joint.loc[(df_joint['Latitude'] >= float(df_24['x_min'])) 
           & (df_joint['Latitude'] <=float(df_24['x_max'])) 
           & (df_joint['Longitude'] >= float(df_24['y_min'])) 
           & (df_joint['Longitude'] <=float(df_24['y_max'])), 'station_flag'] = '24th Mission Street'

df_joint.loc[(df_joint['station_flag']=='24th Mission Street')]
# Out:
#        Unnamed: 0  Exit Station         Exits         tabname  \
# 1860         1860            29  12183.000000  Avg Weekday OD
# 1878         1878            29  12183.000000  Avg Weekday OD
# 1929         1929            29  12183.000000  Avg Weekday OD
# 1988         1988            29  12183.000000  Avg Weekday OD
# 1991         1991            29  12183.000000  Avg Weekday OD
# ...           ...           ...           ...             ...
# 26382       26382            30  12038.894737  Avg Weekday OD
# 26385       26385            30  12038.894737  Avg Weekday OD
# 26394       26394            30  12038.894737  Avg Weekday OD
# 26397       26397            30  12038.894737  Avg Weekday OD
# 26399       26399            30  12038.894737  Avg Weekday OD
#
#               Station Name Analysis Neighborhood               filename  \
# 1860   16th Street Mission               Mission  Ridership_201901.xlsx
# 1878   16th Street Mission               Mission  Ridership_201901.xlsx
# ...

# %%
df_joint.loc[(df_joint['Latitude'] >= float(df_balboa_park['x_min'])) 
           & (df_joint['Latitude'] <=float(df_balboa_park['x_max'])) 
           & (df_joint['Longitude'] >= float(df_balboa_park['y_min'])) 
           & (df_joint['Longitude'] <=float(df_balboa_park['y_max'])), 'station_flag'] = 'Balboa Park'

df_joint.loc[(df_joint['station_flag']=='Balboa Park')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Exit Station, Exits, tabname, Station Name, Analysis Neighborhood, filename, Unnamed: 0.1, index, Incident Datetime, Incident Date, Incident Time, Incident Year, Incident Day of Week, Report Datetime, Row ID, Incident ID, Incident Number, CAD Number, Report Type Code, Report Type Description, Filed Online, Incident Code, Incident Category, Incident Subcategory, Incident Description, Resolution, Intersection, CNN, Police District, Supervisor District, Latitude, Longitude, point, WEEKDAY, station_flag]
# Index: []
#
# [0 rows x 36 columns]

# %%
df_balboa_park
# Out:
#    station_name         lon        lat      x_min      x_max       y_min  \
# 36  BALBOA PARK -122.447129  37.721607  37.719107  37.724107 -122.449629
#
#          y_max
# 36 -122.444629

# %%
df_joint.loc[df_joint['Station Name']=='Balboa Park']
# Out:
#        Unnamed: 0  Exit Station         Exits         tabname Station Name  \
# 3266         3266            32   9755.904762  Avg Weekday OD  Balboa Park
# 3267         3267            32   9755.904762  Avg Weekday OD  Balboa Park
# 3268         3268            32   9755.904762  Avg Weekday OD  Balboa Park
# 3269         3269            32   9755.904762  Avg Weekday OD  Balboa Park
# 3270         3270            32   9755.904762  Avg Weekday OD  Balboa Park
# ...           ...           ...           ...             ...          ...
# 26467       26467            32  10016.210526  Avg Weekday OD  Balboa Park
# 26468       26468            32  10016.210526  Avg Weekday OD  Balboa Park
# 26469       26469            32  10016.210526  Avg Weekday OD  Balboa Park
# 26470       26470            32  10016.210526  Avg Weekday OD  Balboa Park
# 26471       26471            32  10016.210526  Avg Weekday OD  Balboa Park
#
# ...

# %%
df_joint.loc[(df_joint['Latitude'] >= float(df_glen_park['x_min'])) 
           & (df_joint['Latitude'] <=float(df_glen_park['x_max'])) 
           & (df_joint['Longitude'] >= float(df_glen_park['y_min'])) 
           & (df_joint['Longitude'] <=float(df_glen_park['y_max'])), 'station_flag'] = 'Glen Park'

df_joint.loc[(df_joint['station_flag']=='Glen Park')]
# Out:
#        Unnamed: 0  Exit Station        Exits         tabname Station Name  \
# 3251         3251            31  6960.761905  Avg Weekday OD    Glen Park
# 3253         3253            31  6960.761905  Avg Weekday OD    Glen Park
# 3255         3255            31  6960.761905  Avg Weekday OD    Glen Park
# 3256         3256            31  6960.761905  Avg Weekday OD    Glen Park
# 6560         6560            31  6894.181818  Avg Weekday OD    Glen Park
# 6562         6562            31  6894.181818  Avg Weekday OD    Glen Park
# 6564         6564            31  6894.181818  Avg Weekday OD    Glen Park
# 6565         6565            31  6894.181818  Avg Weekday OD    Glen Park
# 9869         9869            31  7146.750000  Avg Weekday OD    Glen Park
# 9871         9871            31  7146.750000  Avg Weekday OD    Glen Park
# 9873         9873            31  7146.750000  Avg Weekday OD    Glen Park
# 9874         9874            31  7146.750000  Avg Weekday OD    Glen Park
# ...

# %%
df_joint.loc[(df_joint['Latitude'] >= float(df_civic_center['x_min'])) 
           & (df_joint['Latitude'] <=float(df_civic_center['x_max'])) 
           & (df_joint['Longitude'] >= float(df_civic_center['y_min'])) 
           & (df_joint['Longitude'] <=float(df_civic_center['y_max'])), 'station_flag'] = 'CIVIC CENTER/ UN PLAZA'

df_joint.loc[(df_joint['station_flag']=='CIVIC CENTER/ UN PLAZA')]
# Out:
#        Unnamed: 0  Exit Station         Exits         tabname  Station Name  \
# 1177         1177            28  21363.809524  Avg Weekday OD  Civic Center
# 1179         1179            28  21363.809524  Avg Weekday OD  Civic Center
# 1205         1205            28  21363.809524  Avg Weekday OD  Civic Center
# 1206         1206            28  21363.809524  Avg Weekday OD  Civic Center
# 1214         1214            28  21363.809524  Avg Weekday OD  Civic Center
# ...           ...           ...           ...             ...           ...
# 24976       24976            28  22529.421053  Avg Weekday OD  Civic Center
# 24988       24988            28  22529.421053  Avg Weekday OD  Civic Center
# 24993       24993            28  22529.421053  Avg Weekday OD  Civic Center
# 24996       24996            28  22529.421053  Avg Weekday OD  Civic Center
# 24999       24999            28  22529.421053  Avg Weekday OD  Civic Center
#
# ...

# %%
df_joint.loc[(df_joint['Latitude'] >= float(df_montgomery['x_min'])) 
           & (df_joint['Latitude'] <=float(df_montgomery['x_max'])) 
           & (df_joint['Longitude'] >= float(df_montgomery['y_min'])) 
           & (df_joint['Longitude'] <=float(df_montgomery['y_max'])), 'station_flag'] = 'Montgomery Street'

df_joint.loc[(df_joint['station_flag']=='Montgomery Street')]
# Out:
#        Unnamed: 0  Exit Station         Exits         tabname   Station Name  \
# 2               2            25  47987.571429  Avg Weekday OD    Embarcadero
# 18             18            25  47987.571429  Avg Weekday OD    Embarcadero
# 20             20            25  47987.571429  Avg Weekday OD    Embarcadero
# 21             21            25  47987.571429  Avg Weekday OD    Embarcadero
# 43             43            25  47987.571429  Avg Weekday OD    Embarcadero
# ...           ...           ...           ...             ...            ...
# 24300       24300            27  25415.526316  Avg Weekday OD  Powell Street
# 24307       24307            27  25415.526316  Avg Weekday OD  Powell Street
# 24322       24322            27  25415.526316  Avg Weekday OD  Powell Street
# 24326       24326            27  25415.526316  Avg Weekday OD  Powell Street
# 24329       24329            27  25415.526316  Avg Weekday OD  Powell Street
#
# ...

# %%
df_joint.loc[(df_joint['Latitude'] >= float(df_powell['x_min'])) 
           & (df_joint['Latitude'] <=float(df_powell['x_max'])) 
           & (df_joint['Longitude'] >= float(df_powell['y_min'])) 
           & (df_joint['Longitude'] <=float(df_powell['y_max'])), 'station_flag'] = 'Powell Street'

df_joint.loc[(df_joint['station_flag']=='Powell Street')]
# Out:
#        Unnamed: 0  Exit Station         Exits         tabname  Station Name  \
# 14             14            25  47987.571429  Avg Weekday OD   Embarcadero
# 16             16            25  47987.571429  Avg Weekday OD   Embarcadero
# 19             19            25  47987.571429  Avg Weekday OD   Embarcadero
# 23             23            25  47987.571429  Avg Weekday OD   Embarcadero
# 31             31            25  47987.571429  Avg Weekday OD   Embarcadero
# ...           ...           ...           ...             ...           ...
# 24960       24960            28  22529.421053  Avg Weekday OD  Civic Center
# 24973       24973            28  22529.421053  Avg Weekday OD  Civic Center
# 24985       24985            28  22529.421053  Avg Weekday OD  Civic Center
# 24992       24992            28  22529.421053  Avg Weekday OD  Civic Center
# 24995       24995            28  22529.421053  Avg Weekday OD  Civic Center
#
# ...

# %%
df_joint['station_flag'].unique()
# Out:
# array([nan, 'Montgomery Street', 'Embarcadero', 'Powell Street',
#        'CIVIC CENTER/ UN PLAZA', '16th Mission Street',
#        '24th Mission Street', 'Glen Park'], dtype=object)

# %%
df_joint.to_csv('df_joint_station_flag.csv')

# %%
df_joint['severity'] = 0
severe_crime = ['Arson', 'Assault', 'Robbery', 'Sex Offense', 'Weapons Offense']
df_joint_severe = df_joint.loc[df_joint['Incident Category'].isin(severe_crime)]
df_joint_severe.loc[df_joint_severe['Incident Category'].isin(severe_crime),'severity']=1
df_joint_severe.to_csv('df_joint_station_flag_severe.csv')
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
